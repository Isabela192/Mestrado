# %%
import pyart
import matplotlib.pyplot as plt

# %%
colors = ['BlueBrown10','BlueBrown11','BrBu10','BrBu12','Bu10','Bu7','BuDOr12','BuDOr18','BuDRd12','BuDRd18',
          'BuGr14','BuGy8','BuOr10','BuOr12','BuOr8','BuOrR14','Carbone11','Carbone17',
          'Carbone42','Cat12','EWilson17','GrMg16','Gray5','Gray9','NWSRef','NWSVel',
          'NWS_SPW','PD17','RRate11','RdYlBu11b','RefDiff','SCook18','StepSeq25','SymGray12',
          'Theodore16','Wild25','LangRainbow12']
# Out:
# ['BlueBrown11', 'BrBu10', 'BrBu12', 'Bu10', 'Bu7', 'BuDOr12', 'BuDOr18', 'BuDRd12', 'BuDRd18']

# %%
radar = pyart.aux_io.read_gamic('./Sao_Roque/2017-02-02/RADL01046020170202191024.mvol')
display = pyart.graph.RadarDisplay(radar)
display.plot('reflectivity', sweep=1, vmin=-32, vmax=20, cmap=colors[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9e28eb1dfe7b> in <module>()
#       1 radar = pyart.aux_io.read_gamic('./Sao_Roque/2017-02-02/RADL01046020170202191024.mvol')
#       2 display = pyart.graph.RadarDisplay(radar)
# ----> 3 display.plot('reflectivity', sweep=1, vmin=-32, vmax=20, cmap=colors[1])
#
# ~/anaconda3/lib/python3.5/site-packages/pyart/graph/radardisplay.py in plot(self, field, sweep, **kwargs)
#     144         """
#     145         if self.scan_type == 'ppi':
# --> 146             self.plot_ppi(field, sweep, **kwargs)
#     147         elif self.scan_type == 'rhi':
#     148             self.plot_rhi(field, sweep, **kwargs)
#
# ...
